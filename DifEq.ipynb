# %%
# %pylab inline
import matplotlib as mpl
mpl.rc('savefig',dpi = 100)
import os
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
p = lambda s,c,x: 0*np.exp((s/c)**.5*x) + np.exp(-(s/c)**.5*x)

# %%
x = np.linspace(0,10,100)
pr = np.array([p(10,2,i) for i in x])
plot(x,pr)

# %%
p1 = lambda L,A,q,c,S,x: A*q/(2*c)*(L*x-x**2)+A*q*L/S
L=1
c = 0.125
q=1e-7
S = 1
x = np.linspace(0,L,100)
pr = np.array([p1(L,L*np.pi*2*.15,q,c,S,i) for i in x])
plot(x,pr)
#yscale('log')

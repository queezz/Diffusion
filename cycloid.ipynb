# %%
import numpy as np
# %pylab inline
import matplotlib as mpl
mpl.rc('savefig',dpi = 100)
import os
import scipy.constants as sc
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
t = np.linspace(0,1e-7,1000)
m = sc.electron_mass
E = 700
B = 1
h = 2*m*E*sc.c**2/(sc.elementary_charge*B**2)
om = sc.elementary_charge*B/(m*sc.c)
x = .5*h*(om*t - np.sin(om*t))
y = .5*h*(1 - np.cos(om*t))
plot(x,y)
print np.pi*h
# Out:
# 2247490749.83
